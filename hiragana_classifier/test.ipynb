# %%
# %run train.py
# %matplotlib inline
# Out:
# 2022-11-19 02:49:40.666355: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-19 02:49:41.683631: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdirectml.d6f03b303ac3c4f2eeb8ca631688c9757b361310.so
# 2022-11-19 02:49:41.683688: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdxcore.so
# 2022-11-19 02:49:41.686294: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libd3d12.so
# 2022-11-19 02:49:42.042373: I tensorflow/c/logging.cc:34] DirectML device enumeration: found 1 compatible adapters.
# Found 54930 files belonging to 46 classes.
# ...

# %%
from train import main

# %%
main()
# Out:
# Found 54930 files belonging to 46 classes.
# Number of layers in the base model:  5
# 2022-11-19 02:59:23.165437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-11-19 02:59:24.877008: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-19 02:59:24.877099: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 25346 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2022-11-19 02:59:24.882810: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...
